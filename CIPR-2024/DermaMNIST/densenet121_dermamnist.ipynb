# %% [markdown]
# Downloading the DermaMNIST dataset

# %%
# !pip install medmnist
from medmnist import DermaMNIST
dataset_train = DermaMNIST(split="train", download=True)
dataset_validate = DermaMNIST(split="val", download=True)
dataset_test = DermaMNIST(split="test", download=True)
# Out:
# Collecting medmnist
#   Downloading medmnist-2.2.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from medmnist) (1.23.5)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from medmnist) (2.0.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from medmnist) (1.2.2)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (from medmnist) (0.21.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from medmnist) (4.66.1)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from medmnist) (9.5.0)
# Collecting fire (from medmnist)
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from medmnist) (2.0.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from medmnist) (0.15.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fire->medmnist) (1.16.0)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from fire->medmnist) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->medmnist) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->medmnist) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->medmnist) (2023.3)
# Requirement already satisfied: scipy>=1.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->medmnist) (1.11.2)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->medmnist) (3.1)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image->medmnist) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image->medmnist) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image->medmnist) (1.4.1)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image->medmnist) (21.3)
# Requirement already satisfied: lazy_loader>=0.2 in /opt/conda/lib/python3.10/site-packages (from scikit-image->medmnist) (0.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->medmnist) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->medmnist) (3.1.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->medmnist) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->medmnist) (4.6.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->medmnist) (1.12)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->medmnist) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision->medmnist) (2.31.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21->scikit-image->medmnist) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->medmnist) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->medmnist) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->medmnist) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->medmnist) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->medmnist) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->medmnist) (1.3.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116932 sha256=6e479e9109ca2909c2b1b4aee95b06bcd774dfcbffbd121ea2929077e6cca266
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# Installing collected packages: fire, medmnist
# Successfully installed fire-0.5.0 medmnist-2.2.3
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Downloading https://zenodo.org/records/6496656/files/dermamnist.npz to /root/.medmnist/dermamnist.npz
# 100%|██████████| 19725078/19725078 [00:22<00:00, 872034.48it/s]
# Using downloaded and verified file: /root/.medmnist/dermamnist.npz
# Using downloaded and verified file: /root/.medmnist/dermamnist.npz

# %% [markdown]
# Required Imports

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.image import imread
import os
import shutil
import skimage
import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
from keras import backend as K
from glob import glob
from tensorflow import keras
from tensorflow.keras import layers, models
from keras.applications.imagenet_utils import preprocess_input
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, accuracy_score, roc_curve, auc, roc_auc_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Layer,InputSpec,concatenate,Dense, Conv2D, MaxPooling2D, Flatten,Input,Activation,add,AveragePooling2D,GlobalAveragePooling2D,BatchNormalization,Dropout, Reshape
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam, SGD, RMSprop

# %% [markdown]
# Shape of the dataset - Analyzing the dataset

# %%
x_train, y_train = dataset_train.imgs, dataset_train.labels
x_test, y_test = dataset_test.imgs, dataset_test.labels
x_val, y_val = dataset_validate.imgs, dataset_validate.labels

print(x_train.shape, y_train.shape, x_train[0].shape)
print(x_test.shape, y_test.shape, x_train[0].shape)
print(x_val.shape, y_val.shape, x_train[0].shape)
# Out:
# (7007, 28, 28, 3) (7007, 1) (28, 28, 3)
# (2005, 28, 28, 3) (2005, 1) (28, 28, 3)
# (1003, 28, 28, 3) (1003, 1) (28, 28, 3)

# %% [markdown]
# Preprocessing the images - Resizing

# %%
def preprocess_images(images):
    preprocessed_images = []
    for image in images:
        resized_image = cv2.resize(image, (192, 192))
        preprocessed_images = resized_image
    return np.array(preprocessed_images)

# %% [markdown]
# New Shape of the images - Train/Test/Validation

# %%
# Convert the labels to 3D tensors
y_train = tf.expand_dims(y_train, -1)
resize_x_train = tf.image.resize(x_train, (192, 192))
resize_y_train = tf.image.resize(y_train, (192, 192))
print(y_train.shape)
print(resize_x_train.shape,resize_y_train.shape)
# Out:
# (7007, 1, 1)
# (7007, 192, 192, 3) (192, 192, 1)

# %%
# Convert the labels to 3D tensors
y_val = tf.expand_dims(y_val, -1)
resize_x_val = tf.image.resize(x_val, (192, 192))
resize_y_val = tf.image.resize(y_val, (192, 192))
print(y_val.shape)
print(resize_x_val.shape,resize_y_val.shape)
# Out:
# (1003, 1, 1)
# (1003, 192, 192, 3) (192, 192, 1)

# %%
# Convert the labels to 3D tensors
y_test = tf.expand_dims(y_test, -1)
resize_x_test = tf.image.resize(x_test, (192, 192))
resize_y_test = tf.image.resize(y_test, (192, 192))
print(y_test.shape)
print(resize_x_test.shape,resize_y_test.shape)
# Out:
# (2005, 1, 1)
# (2005, 192, 192, 3) (192, 192, 1)

# %%
input_shape = (192,192,3)
input_layer = Input(shape=input_shape)

# %% [markdown]
# Preparing the Base Model - Densenet121

# %%
from tensorflow.keras.applications.densenet import DenseNet121

densenet121_base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=input_shape)
for layer in densenet121_base_model.layers:
    layer.trainable = True

x = densenet121_base_model(input_layer)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
outputdensenet121 = tf.keras.layers.Dense(7, activation='softmax')(x)

model_densenet121 = Model(inputs=input_layer, outputs=outputdensenet121)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step

# %% [markdown]
# Model Architecture

# %%
from tensorflow.keras.utils import plot_model
image_path = 'model_architecture_densenet121.png'
plot_model(model_densenet121, to_file=image_path, show_shapes=True, show_layer_names=True)

# %% [markdown]
# Compilance and Callbacks

# %%
# Compile the model
model_densenet121.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Implement learning rate scheduling
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1)

# Implement early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, restore_best_weights=True)

# %% [markdown]
# Fitting the data

# %%
history_densenet121 = model_densenet121.fit(
    resize_x_train,
    y_train,
    epochs=100,
    validation_data=(resize_x_val, y_val),
    callbacks=[lr_scheduler, early_stopping]
)
# Out:
# Epoch 1/100
# 219/219 [==============================] - 115s 186ms/step - loss: 0.8545 - accuracy: 0.6972 - val_loss: 2.6139 - val_accuracy: 0.5434 - lr: 0.0010
# Epoch 2/100
# 219/219 [==============================] - 34s 156ms/step - loss: 0.7622 - accuracy: 0.7177 - val_loss: 0.8481 - val_accuracy: 0.6849 - lr: 0.0010
# Epoch 3/100
# 219/219 [==============================] - 35s 160ms/step - loss: 0.7182 - accuracy: 0.7356 - val_loss: 1.0381 - val_accuracy: 0.6281 - lr: 0.0010
# Epoch 4/100
# 219/219 [==============================] - 34s 155ms/step - loss: 0.7314 - accuracy: 0.7337 - val_loss: 1.2235 - val_accuracy: 0.7059 - lr: 0.0010
# Epoch 5/100
# 219/219 [==============================] - 35s 161ms/step - loss: 0.6757 - accuracy: 0.7525 - val_loss: 0.9099 - val_accuracy: 0.6550 - lr: 0.0010
# Epoch 6/100
# 219/219 [==============================] - 34s 156ms/step - loss: 0.6447 - accuracy: 0.7565 - val_loss: 0.7810 - val_accuracy: 0.6820 - lr: 0.0010
# Epoch 7/100
# 219/219 [==============================] - 35s 161ms/step - loss: 0.6253 - accuracy: 0.7674 - val_loss: 0.7721 - val_accuracy: 0.6590 - lr: 0.0010
# Epoch 8/100
# 219/219 [==============================] - 35s 161ms/step - loss: 0.6093 - accuracy: 0.7689 - val_loss: 0.8502 - val_accuracy: 0.7159 - lr: 0.0010
# Epoch 9/100
# 219/219 [==============================] - 34s 156ms/step - loss: 0.5965 - accuracy: 0.7725 - val_loss: 0.8694 - val_accuracy: 0.7268 - lr: 0.0010
# Epoch 10/100
# 219/219 [==============================] - 35s 161ms/step - loss: 0.6063 - accuracy: 0.7764 - val_loss: 2.0108 - val_accuracy: 0.6221 - lr: 0.0010
# Epoch 11/100
# 219/219 [==============================] - 34s 156ms/step - loss: 0.5843 - accuracy: 0.7778 - val_loss: 1.4179 - val_accuracy: 0.5424 - lr: 0.0010
# Epoch 12/100
# 219/219 [==============================] - ETA: 0s - loss: 0.5558 - accuracy: 0.7909
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 219/219 [==============================] - 35s 162ms/step - loss: 0.5558 - accuracy: 0.7909 - val_loss: 0.9394 - val_accuracy: 0.7119 - lr: 0.0010
# Epoch 13/100
# 219/219 [==============================] - 35s 162ms/step - loss: 0.4410 - accuracy: 0.8356 - val_loss: 0.6078 - val_accuracy: 0.7707 - lr: 1.0000e-04
# Epoch 14/100
# 219/219 [==============================] - 34s 155ms/step - loss: 0.3618 - accuracy: 0.8621 - val_loss: 0.6345 - val_accuracy: 0.7777 - lr: 1.0000e-04
# Epoch 15/100
# 219/219 [==============================] - 35s 161ms/step - loss: 0.3134 - accuracy: 0.8790 - val_loss: 0.6987 - val_accuracy: 0.7807 - lr: 1.0000e-04
# Epoch 16/100
# 219/219 [==============================] - 34s 156ms/step - loss: 0.2616 - accuracy: 0.8995 - val_loss: 0.7327 - val_accuracy: 0.7697 - lr: 1.0000e-04
# Epoch 17/100
# 219/219 [==============================] - 34s 156ms/step - loss: 0.2067 - accuracy: 0.9245 - val_loss: 0.7878 - val_accuracy: 0.7707 - lr: 1.0000e-04
# Epoch 18/100
# 219/219 [==============================] - ETA: 0s - loss: 0.1554 - accuracy: 0.9448
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 219/219 [==============================] - 35s 161ms/step - loss: 0.1554 - accuracy: 0.9448 - val_loss: 0.8800 - val_accuracy: 0.7687 - lr: 1.0000e-04
# Epoch 19/100
# 219/219 [==============================] - 34s 155ms/step - loss: 0.0977 - accuracy: 0.9733 - val_loss: 0.8677 - val_accuracy: 0.7627 - lr: 1.0000e-05
# Epoch 20/100
# 219/219 [==============================] - 34s 155ms/step - loss: 0.0845 - accuracy: 0.9773 - val_loss: 0.8869 - val_accuracy: 0.7697 - lr: 1.0000e-05
# Epoch 21/100
# 219/219 [==============================] - 34s 156ms/step - loss: 0.0757 - accuracy: 0.9799 - val_loss: 0.8976 - val_accuracy: 0.7747 - lr: 1.0000e-05
# Epoch 22/100
# 219/219 [==============================] - 35s 161ms/step - loss: 0.0699 - accuracy: 0.9837 - val_loss: 0.9112 - val_accuracy: 0.7697 - lr: 1.0000e-05
# Epoch 23/100
# 219/219 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9837
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 219/219 [==============================] - 34s 155ms/step - loss: 0.0642 - accuracy: 0.9837 - val_loss: 0.9266 - val_accuracy: 0.7717 - lr: 1.0000e-05
# Epoch 24/100
# 219/219 [==============================] - 35s 161ms/step - loss: 0.0618 - accuracy: 0.9870 - val_loss: 0.9317 - val_accuracy: 0.7717 - lr: 1.0000e-06
# Epoch 25/100
# 219/219 [==============================] - 34s 155ms/step - loss: 0.0656 - accuracy: 0.9836 - val_loss: 0.9324 - val_accuracy: 0.7697 - lr: 1.0000e-06
# Epoch 26/100
# 219/219 [==============================] - 34s 156ms/step - loss: 0.0616 - accuracy: 0.9846 - val_loss: 0.9343 - val_accuracy: 0.7697 - lr: 1.0000e-06
# Epoch 27/100
# 219/219 [==============================] - 35s 161ms/step - loss: 0.0551 - accuracy: 0.9886 - val_loss: 0.9338 - val_accuracy: 0.7687 - lr: 1.0000e-06
# Epoch 28/100
# 219/219 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9874
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 219/219 [==============================] - 35s 161ms/step - loss: 0.0575 - accuracy: 0.9874 - val_loss: 0.9364 - val_accuracy: 0.7697 - lr: 1.0000e-06
# Epoch 29/100
# 219/219 [==============================] - 34s 155ms/step - loss: 0.0589 - accuracy: 0.9872 - val_loss: 0.9394 - val_accuracy: 0.7687 - lr: 1.0000e-07
# Epoch 30/100
# 219/219 [==============================] - 35s 161ms/step - loss: 0.0574 - accuracy: 0.9880 - val_loss: 0.9378 - val_accuracy: 0.7697 - lr: 1.0000e-07
# Epoch 31/100
# 219/219 [==============================] - 35s 161ms/step - loss: 0.0580 - accuracy: 0.9880 - val_loss: 0.9393 - val_accuracy: 0.7707 - lr: 1.0000e-07
# Epoch 32/100
# 219/219 [==============================] - 35s 161ms/step - loss: 0.0585 - accuracy: 0.9877 - val_loss: 0.9393 - val_accuracy: 0.7697 - lr: 1.0000e-07
# Epoch 33/100
# 219/219 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9873
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Restoring model weights from the end of the best epoch: 13.
# 219/219 [==============================] - 36s 163ms/step - loss: 0.0570 - accuracy: 0.9873 - val_loss: 0.9375 - val_accuracy: 0.7697 - lr: 1.0000e-07
# Epoch 33: early stopping

# %% [markdown]
# Saving the trained model

# %%
model_densenet121.save('DermaMNIST_DenseNet121.h5')

# %% [markdown]
# Loss-Accuracy Graphs

# %%
plt.subplots(figsize=(6,4))
plt.plot(history_densenet121.epoch, history_densenet121.history["loss"], color="orange", label="Train Loss")
plt.plot(history_densenet121.epoch, history_densenet121.history["val_loss"], color="blue",
label="Validation Loss")
plt.xlabel("Epoch Number")
plt.ylabel("Loss")
plt.legend()
plt.title("Loss Graph DenseNet121")
plt.show()

# %%
plt.subplots(figsize=(6,4))
plt.plot(history_densenet121.epoch, history_densenet121.history["accuracy"], color="orange",
label="Train Accuracy")
plt.plot(history_densenet121.epoch, history_densenet121.history["val_accuracy"], color="blue",
label="Validation Accuracy")
plt.xlabel("Epoch Number")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Accuracy Graph DenseNet121")
plt.show()

# %% [markdown]
# Evaluation of the model

# %%
model_densenet121.evaluate(resize_x_test, y_test)
# Out:
# 63/63 [==============================] - 4s 64ms/step - loss: 0.5720 - accuracy: 0.7825
# [0.5720335245132446, 0.7825436592102051]
